# %% [markdown]
# # Mapy interaktywne

# %% [markdown]
# ***Autor: Adam Dąbkowski***

# %% [markdown]
# ## 0. Importowanie niezbędnych bibliotek

# %%
import pandas as pd
import plotly.express as px

from ipywidgets import interact, widgets

# %% [markdown]
# ## 1. Wczytywanie zbioru danych

# %% [markdown]
# Źródło danych: ***https://www.kaggle.com/datasets/ujwalkandi/unesco-world-heritage-sites/data***

# %%
DATASET_PATH: str = "whc-sites-2019.csv"

# %%
df = pd.read_csv(DATASET_PATH, low_memory=False)
df.head(n=100)
# Out:
#     category states_name_en                        region_en  unique_number  \
# 0   Cultural    Afghanistan             Asia and the Pacific            230
# 1   Cultural    Afghanistan             Asia and the Pacific            234
# 2   Cultural        Albania         Europe and North America           1590
# 3   Cultural        Albania         Europe and North America           1563
# 4   Cultural        Algeria                      Arab States            111
# ..       ...            ...                              ...            ...
# 95   Natural         Brazil  Latin America and the Caribbean           1044
# 96   Natural         Brazil  Latin America and the Caribbean           1045
# 97  Cultural         Brazil  Latin America and the Caribbean           1157
# 98   Natural         Brazil  Latin America and the Caribbean           1163
# 99   Natural         Brazil  Latin America and the Caribbean           1164
#
#     id_no   rev_bis                                            name_en  \
# 0     208       Rev  Cultural Landscape and Archaeological Remains ...
# 1     211       Rev          Minaret and Archaeological Remains of Jam
# 2     569       Bis         Historic Centres of Berat and Gjirokastra
# 3     570       ter                                            Butrint
# 4     102       NaN                            Al Qal'a of Beni Hammad
# ..    ...       ...                                                ...
# 95    892       Rev           Discovery Coast Atlantic Forest Reserves
# 96    893  -894 Rev                Atlantic Forest South-East Reserves
# 97    993       Rev               Historic Centre of the Town of Goiás
# 98    998       Bis                Central Amazon Conservation Complex
# 99    999       NaN                         Pantanal Conservation Area
#
#                                  short_description_en  \
# 0    The cultural landscape and archaeological rem...
# 1    The 65m-tall Minaret of Jam is a graceful, so...
# 2    Berat and Gjirokastra are inscribed as rare e...
# 3    Inhabited since prehistoric times, Butrint ha...
# 4    In a mountainous site of extraordinary beauty...
# ..                                                ...
# 95   The Discovery Coast Atlantic Forest Reserves,...
# 96   The Atlantic Forest South-East Reserves, in t...
# 97   Goiás testifies to the occupation and coloniz...
# 98   The Central Amazon Conservation Complex makes...
# 99   The Pantanal Conservation Area consists of a ...
#
#                                      justification_en  date_inscribed  ...  \
# 0    <em>Criterion (i):</em> The Buddha statues an...            2003  ...
# 1    <em>Criterion (ii):</em> The innovative archi...            2002  ...
# 2                                                 NaN            2005  ...
# 3                                                 NaN            1992  ...
# 4                                                 NaN            1980  ...
# ..                                                ...             ...  ...
# 95   <em>Criterion (ix):</em> The Brazilian Discov...            1999  ...
# 96   The Atlantic Forests (Southeast) contain the ...            1999  ...
# 97   <em>Criterion ii:</em> In its layout and arch...            2001  ...
# 98   <em>Criterion (ix):</em> The varzea and igap&...            2000  ...
# 99   <em>Criteria (vii), (ix) and (x):</em> The si...            2000  ...
#
#    date_end  danger_list  longitude   latitude  area_hectares  \
# 0       NaN       Y 2003  67.825250  34.846940   1.589265e+02
# 1       NaN       Y 2002  64.515889  34.396417   7.000000e+01
# 2       NaN          NaN  20.133333  40.069444   5.890000e+01
# 3    2005.0  P 1997-2005  20.026111  39.751111            NaN
# 4       NaN          NaN   4.786840  35.818440   1.500000e+02
# ..      ...          ...        ...        ...            ...
# 95      NaN          NaN -39.250000 -16.500000   1.119300e+05
# 96      NaN          NaN -48.000000 -24.166670   4.681930e+05
# 97      NaN          NaN -50.133360 -15.933280   4.030000e+01
# 98      NaN          NaN -62.008333  -2.333333   5.323018e+06
# 99      NaN          NaN -57.383330 -17.716670   1.878180e+05
#
#             criteria_txt  category_short iso_code udnp_code transboundary
# 0   (i)(ii)(iii)(iv)(vi)               C       af       afg             0
# 1          (ii)(iii)(iv)               C       af       afg             0
# 2              (iii)(iv)               C       al       alb             0
# 3                  (iii)               C       al       alb             0
# 4                  (iii)               C       dz       dza             0
# ..                   ...             ...      ...       ...           ...
# 95               (ix)(x)               N       br       bra             0
# 96          (vii)(ix)(x)               N       br       bra             0
# 97              (ii)(iv)               C       br       bra             0
# 98               (ix)(x)               N       br       bra             0
# 99          (vii)(ix)(x)               N       br       bra             0
#
# [100 rows x 22 columns]

# %% [markdown]
# ## 2. Wizualizacja danych

# %% [markdown]
# #### 2.1 Implementacja funkcji pomocniczych

# %%
def wrap_text(text, width=50):
    if not isinstance(text, str):
        return text
    
    words = text.split()
    wrapped_lines = []
    current_line = []
    current_length = 0

    for word in words:
        if current_length + len(word) + 1 > width:
            wrapped_lines.append(' '.join(current_line))
            current_line = [word]
            current_length = len(word) + 1
        else:
            current_line.append(word)
            current_length += len(word) + 1

    if current_line:
        wrapped_lines.append(' '.join(current_line))

    return '<br>'.join(wrapped_lines)

# %% [markdown]
# #### 2.2 Generacja interaktywnej mapy

# %%
df['date_inscribed'] = pd.to_numeric(df['date_inscribed'], errors='coerce')

regions = ['All'] + df['region_en'].dropna().unique().tolist()
countries = ['All'] + df['states_name_en'].dropna().unique().tolist()

global_min_year = 1978
global_max_year = int(df['date_inscribed'].max())

region_widget = widgets.Dropdown(
    options=regions,
    value='All',
    description='Region:'
)

country_widget = widgets.Dropdown(
    options=countries,
    value='All',
    description='Country:'
)

min_year_widget = widgets.IntSlider(
    value=global_min_year,
    min=global_min_year,
    max=global_max_year,
    step=1,
    description='Min Year:',
    continuous_update=False
)

max_year_widget = widgets.IntSlider(
    value=global_max_year,
    min=global_min_year,
    max=global_max_year,
    step=1,
    description='Max Year:',
    continuous_update=False
)

def update_countries(region):
    if region == 'All':
        countries = ['All'] + df['states_name_en'].dropna().unique().tolist()
    else:
        countries = ['All'] + df[df['region_en'] == region]['states_name_en'].dropna().unique().tolist()
    country_widget.options = countries

region_widget.observe(lambda change: update_countries(change.new), names='value')

def update_map(region='All', country='All', min_year=global_min_year, max_year=global_max_year):
    if region == 'All':
        filtered_data = df
    else:
        filtered_data = df[df['region_en'] == region]

    if country != 'All':
        filtered_data = filtered_data[filtered_data['states_name_en'] == country]

    filtered_data = filtered_data[
        (filtered_data['date_inscribed'] >= min_year) &
        (filtered_data['date_inscribed'] <= max_year)
    ]

    filtered_data = filtered_data.copy()

    if filtered_data.empty:
        fig = px.scatter_geo(
            data_frame=None,
            lat=None,
            lon=None,
            title="UNESCO World Heritage Sites - No data available for the selected filters",
            projection="natural earth"
        )
    else:
        fig = px.scatter_geo(
            filtered_data,
            lat='latitude',
            lon='longitude',
            hover_name='name_en',
            hover_data=['category', 'region_en', 'date_inscribed', 'short_description_en'],
            color='category',
            title=f"UNESCO World Heritage Sites - {country if country != 'All' else (region if region != 'All' else 'All Regions')} ({min_year}-{max_year})",
            projection="natural earth"
        )
        
        filtered_data['wrapped_description'] = filtered_data['short_description_en'].apply(lambda x: wrap_text(x))
        
        fig.update_traces(
            hovertemplate=(
                "<b>%{hovertext}</b><br><br>" +
                "Category: %{customdata[0]}<br>" +
                "Region: %{customdata[1]}<br>" +
                "Year Inscribed: %{customdata[2]}<br><br>" +
                "Description:<br>%{customdata[3]}<extra></extra>"
            ),
            customdata=filtered_data[['category', 'region_en', 'date_inscribed', 'wrapped_description']].values,
            hovertext=filtered_data['name_en']
        )

    fig.update_layout(
        geo=dict(
            projection_scale=1.4,
            showland=True,
            landcolor="lightgray",
            showcountries=True,
            countrycolor="darkgray",
            showocean=True,
            oceancolor="azure",
            showframe=False,
        ),
        width=1110,
        height=650,
        margin={"r": 0, "t": 40, "l": 0, "b": 0},
        title={
            'y': 0.95,
            'x': 0.5,
            'xanchor': 'center',
            'yanchor': 'top',
            'font': {'size': 20, 'color': 'black'}
        }
    )

    fig.show()

interact(update_map, region=region_widget, country=country_widget, min_year=min_year_widget, max_year=max_year_widget)
# Out:
# interactive(children=(Dropdown(description='Region:', options=('All', 'Asia and the Pacific', 'Europe and Nort…
# <function __main__.update_map(region='All', country='All', min_year=1978, max_year=2019)>
